# %%
import pandas as pd
from sqlalchemy import create_engine
from bokeh.plotting import figure, output_file, show,output_notebook
import math
from ast import literal_eval
from bokeh.tile_providers import CARTODBPOSITRON

# %%
def redshift():
    global eng
    with open('/home/mnamoff/Credentials/MXRedshift_user') as user_file:
        username = user_file.read()
    with open('/home/mnamoff/Credentials/MXRedshift_pw') as user_pass:
        password = user_pass.read()
    eng = create_engine("postgres://" + username + ":" + password + "@prd-jj-redshift-rds.c1iaphtcvqvg.us-east-1.redshift.amazonaws.com:5439/rds")
    return(eng)
redshift()
# Out:
# Engine(postgres://rds_read:***@prd-jj-redshift-rds.c1iaphtcvqvg.us-east-1.redshift.amazonaws.com:5439/rds)

# %%
q = """

select jjdma_name, latitude,longitude 
from __storesupporttable
WHERE storenumber IN (4,17,19,28,41,43,44,54,61,75,78,80,88,96,98,100,102,104,105,106,113,116,117,119,120,121,123,131,135,136,137,150,156,157,158,161,162,168,169,170,171,172,173,174,181,184,187,188,189,190,191,192,202,203,204,205,215,220,227,228,230,232,233,244,245,246,248,249,251,255,256,257,258,259,260,261,262,266,271,272,276,277,278,279,280,281,282,286,290,295,300,301,303,305,306,307,308,309,310,311,312,326,329,331,345,348,350,357,359,360,364,365,366,368,371,373,374,378,379,380,381,382,384,385,387,389,390,391,393,394,397,398,399,401,402,403,405,406,409,410,412,413,414,415,416,417,418,419,420,421,422,423,424,427,430,432,435,436,437,438,440,441,442,444,446,447,448,451,452,455,456,458,459,463,466,467,469,471,472,473,474,475,476,478,479,480,482,483,485,486,487,488,490,491,492,495,496,497,498,499,500,501,502,503,504,505,506,510,511,513,514,516,517,518,519,522,524,526,527,528,529,530,531,533,535,538,539,543,544,545,546,548,549,550,551,552,557,558,559,561,562,565,566,568,569,570,571,572,573,574,575,576,578,579,580,581,583,586,587,588,590,592,593,594,596,597,599,600,601,602,603,604,607,608,609,611,612,613,615,616,618,621,622,625,629,632,633,634,635,636,639,640,641,643,646,647,648,649,650,651,652,655,657,658,660,661,665,666,669,670,671,673,674,675,679,681,683,685,686,688,690,691,692,694,697,698,700,702,703,704,709,711,712,713,714,716,717,719,720,723,724,725,728,730,732,733,734,735,736,737,738,739,743,746,747,748,749,750,752,753,754,755,756,757,759,760,762,766,769,770,771,773,774,775,776,778,780,783,788,789,790,794,796,797,799,800,802,803,804,807,808,811,812,813,814,815,816,817,822,826,828,829,830,836,838,841,842,845,848,849,850,852,854,857,858,859,860,862,863,866,867,869,874,878,879,880,883,887,888,889,890,893,896,900,901,903,904,905,906,908,909,910,911,913,914,915,916,919,921,922,923,924,925,928,931,934,935,936,937,939,940,943,944,945,946,949,950,951,952,953,954,961,962,964,965,966,967,968,969,971,973,974,975,979,982,983,984,985,986,987,990,993,994,995,999,1000,1002,1004,1005,1009,1010,1011,1012,1013,1014,1016,1017,1018,1019,1020,1021,1022,1025,1026,1028,1029,1030,1032,1033,1034,1036,1037,1038,1040,1042,1047,1049,1051,1056,1057,1061,1062,1063,1065,1067,1068,
944,3947,3962,3969,3970,3984,3995,4007,4018,4019,4021,4022,4023,4024,4025,4026,4031,4038,4049,4051,4052,4053,4054,4055,4056,4057,4058,4060,4061,4062,4063,4100,4105,4152,4160,4166,4168,4178,9003,9006,9008,9011,9012,9015,9016,9017,9018,9019,9020,9021,9024,9026,9028,9030,9031,9036,9039,9040,9043,9044,9045,9048,9051,9052,9053,9054,9055,9060,9061,9062,9063,9076,9078)
"""

# %%
L_Map = pd.read_sql_query(q, eng)

# %%
L_Map.head()
# Out:
#              jjdma_name   latitude  longitude
# 0             St. Louis  38.626942 -90.189744
# 1               Chicago  41.600352 -87.792825
# 2  La Crosse-Eau Claire  44.800090 -91.471250
# 3               Chicago  41.561656 -87.514351
# 4               Houston  30.020376 -95.527023

# %%
L_Map['Location'] = "(" + L_Map['latitude'].astype(str) + ", " + L_Map['longitude'].astype(str) + ")"

# %%
L_Map.head()
# Out:
#              jjdma_name   latitude  longitude  \
# 0             St. Louis  38.626942 -90.189744
# 1               Chicago  41.600352 -87.792825
# 2  La Crosse-Eau Claire  44.800090 -91.471250
# 3               Chicago  41.561656 -87.514351
# 4               Houston  30.020376 -95.527023
#
#                                 Location
# 0               (38.626942, -90.1897435)
# 1              (41.6003517, -87.7928251)
# 2                  (44.80009, -91.47125)
# 3               (41.561656, -87.5143511)
# 4  (30.0203762054443, -95.5270233154297)

# %%
def merc(Coords):
    Coordinates = literal_eval(Coords)
    lat = Coordinates[0]
    lon = Coordinates[1]
    
    r_major = 6378137.000
    x = r_major * math.radians(lon)
    scale = x/lon
    y = 180.0/math.pi * math.log(math.tan(math.pi/4.0 + 
        lat * (math.pi/180.0)/2.0)) * scale
    return (x, y)

# %%
merc('(41.857908, -87.669147)')
# Out:
# (-9759284.802320646, 5139718.458609748)

# %%
L_Map['coords_x'] = L_Map['Location'].apply(lambda x: merc(x)[0])
L_Map['coords_y'] = L_Map['Location'].apply(lambda x: merc(x)[1])

# %%
L_Map.head()
# Out:
#              jjdma_name   latitude  longitude  \
# 0             St. Louis  38.626942 -90.189744
# 1               Chicago  41.600352 -87.792825
# 2  La Crosse-Eau Claire  44.800090 -91.471250
# 3               Chicago  41.561656 -87.514351
# 4               Houston  30.020376 -95.527023
#
#                                 Location      coords_x      coords_y
# 0               (38.626942, -90.1897435) -1.003988e+07  4.668374e+06
# 1              (41.6003517, -87.7928251) -9.773053e+06  5.101301e+06
# 2                  (44.80009, -91.47125) -1.018253e+07  5.590104e+06
# 3               (41.561656, -87.5143511) -9.742053e+06  5.095542e+06
# 4  (30.0203762054443, -95.5270233154297) -1.063402e+07  3.506169e+06

# %%
p = figure(x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(CARTODBPOSITRON)
# Out:
# TileRenderer(id='1042', ...)

# %%
p.circle(x = L_Map['coords_x'],
         y = L_Map['coords_y'])
# Out:
# GlyphRenderer(id='1049', ...)

# %%
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1053">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7fd20cdc-a026-4f80-a458-31cd2a515626" data-root-id="1002"></div>
